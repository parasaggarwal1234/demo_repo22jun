# %%
import pandas as pd
import numpy as np

# %%
# dataFrame 1
d1 = {'Customer_id':[1,2,3,4,5,6],
     'Product':['Oven','Oven','Oven','Television','Television','Television']}
df1 = pd.DataFrame(d1)
 
# data frame 2
d2 = {'Customer_id':[2,4,6,7,8],
    'State':['California','California','Texas','Austria','Spain']}
df2 = pd.DataFrame(d2)

# %%
df1
# Out:
#    Customer_id     Product
# 0            1        Oven
# 1            2        Oven
# 2            3        Oven
# 3            4  Television
# 4            5  Television
# 5            6  Television

# %%
df2
# Out:
#    Customer_id       State
# 0            2  California
# 1            4  California
# 2            6       Texas
# 3            7     Austria
# 4            8       Spain

# %% [markdown]
# ### Merge
#
# <b>inner : </b> Return only the rows in which the left table has matching keys in the right table

# %%
# Inner  
d1 = pd.merge(df1, df2, on='Customer_id', how='inner')
# d1[['Product','State']]
d1
# Out:
#    Customer_id     Product       State
# 0            2        Oven  California
# 1            4  Television  California
# 2            6  Television       Texas

# %% [markdown]
# <b>outer :</b> Returns all rows from both the tables

# %%
d2 = pd.merge(df1, df2, on='Customer_id', how='outer')
d2
# Out:
#    Customer_id     Product       State
# 0            1        Oven         NaN
# 1            2        Oven  California
# 2            3        Oven         NaN
# 3            4  Television  California
# 4            5  Television         NaN
# 5            6  Television       Texas
# 6            7         NaN     Austria
# 7            8         NaN       Spain

# %% [markdown]
# <b>Left : </b> Return all rows from the left table, and rows with matching keys from the right table.

# %%
d3 = pd.merge(df1, df2, on='Customer_id', how='left')
d3
# Out:
#    Customer_id     Product       State
# 0            1        Oven         NaN
# 1            2        Oven  California
# 2            3        Oven         NaN
# 3            4  Television  California
# 4            5  Television         NaN
# 5            6  Television       Texas

# %% [markdown]
# <b>Right :</b> Return all rows from the right table, and rows with matching keys from the left table.

# %%
d4 = pd.merge(df1, df2, on='Customer_id', how='right')
d4
# Out:
#    Customer_id     Product       State
# 0            2        Oven  California
# 1            4  Television  California
# 2            6  Television       Texas
# 3            7         NaN     Austria
# 4            8         NaN       Spain

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (6, 2)
# (5, 2)

# %% [markdown]
# #### Cross
# It returns cartesian product.<br>
# For each row of table1, each and every row of table2 will fetched as the result

# %%
d5 = pd.merge(df1, df2, how='cross')
d5.head(10)
# Out:
#    Customer_id_x Product  Customer_id_y       State
# 0              1    Oven              2  California
# 1              1    Oven              4  California
# 2              1    Oven              6       Texas
# 3              1    Oven              7     Austria
# 4              1    Oven              8       Spain
# 5              2    Oven              2  California
# 6              2    Oven              4  California
# 7              2    Oven              6       Texas
# 8              2    Oven              7     Austria
# 9              2    Oven              8       Spain

# %% [markdown]
# ### Using merge with more than one columns in common

# %%
# dataFrame 1
da1 = {'Customer_id':[1,2,3,4,5,6],
       'Name':['Ashish','Ridhima','Aanya','Akhilesh','Kunal','Shreya'],
      'Product':['Oven','Oven','Oven','Television','Television','Television']}
dfr1 = pd.DataFrame(da1)
 
# data frame 2
da2 = {'Customer_id':[2,4,6,7,8],
       'Name':['Ridhima','Akhilesh','Shreya','Watson','Vyshakh'],
       'State':['California','California','Texas','Austria','Spain']}
dfr2 = pd.DataFrame(da2)

# %%
dfr1
# Out:
#    Customer_id      Name     Product
# 0            1    Ashish        Oven
# 1            2   Ridhima        Oven
# 2            3     Aanya        Oven
# 3            4  Akhilesh  Television
# 4            5     Kunal  Television
# 5            6    Shreya  Television

# %%
dfr2
# Out:
#    Customer_id      Name       State
# 0            2   Ridhima  California
# 1            4  Akhilesh  California
# 2            6    Shreya       Texas
# 3            7    Watson     Austria
# 4            8   Vyshakh       Spain

# %%
r0 = pd.merge(dfr1, dfr2, how='inner')
r0
# Out:
#    Customer_id      Name     Product       State
# 0            2   Ridhima        Oven  California
# 1            4  Akhilesh  Television  California
# 2            6    Shreya  Television       Texas

# %% [markdown]
# #### 1) Inner merge based on two columns

# %%
r1 = pd.merge(dfr1, dfr2, on=['Customer_id','Name'], how='inner')
r1
# Out:
#    Customer_id      Name     Product       State
# 0            2   Ridhima        Oven  California
# 1            4  Akhilesh  Television  California
# 2            6    Shreya  Television       Texas

# %% [markdown]
# #### 2) Outer merge based on two columns

# %%
r2 = pd.merge(dfr1, dfr2, on=['Customer_id','Name'], how='outer')
r2
# Out:
#    Customer_id      Name     Product       State
# 0            1    Ashish        Oven         NaN
# 1            2   Ridhima        Oven  California
# 2            3     Aanya        Oven         NaN
# 3            4  Akhilesh  Television  California
# 4            5     Kunal  Television         NaN
# 5            6    Shreya  Television       Texas
# 6            7    Watson         NaN     Austria
# 7            8   Vyshakh         NaN       Spain

# %% [markdown]
# #### 3) Left merge based on two columns

# %%
r3 = pd.merge(dfr1, dfr2, on=['Customer_id','Name'], how='left')
r3
# Out:
#    Customer_id      Name     Product       State
# 0            1    Ashish        Oven         NaN
# 1            2   Ridhima        Oven  California
# 2            3     Aanya        Oven         NaN
# 3            4  Akhilesh  Television  California
# 4            5     Kunal  Television         NaN
# 5            6    Shreya  Television       Texas

# %% [markdown]
# #### 4) Right merge baed on two columns

# %%
r4 = pd.merge(dfr1, dfr2, on=['Customer_id','Name'], how='right')
r4
# Out:
#    Customer_id      Name     Product       State
# 0            2   Ridhima        Oven  California
# 1            4  Akhilesh  Television  California
# 2            6    Shreya  Television       Texas
# 3            7    Watson         NaN     Austria
# 4            8   Vyshakh         NaN       Spain

# %% [markdown]
# ### Append

# %%
ls1 = [['Ranjeet',44],['Mukul',88],['Sneha',79]]
df1 = pd.DataFrame(ls1, columns=['Name','Marks'])
df1
# Out:
#       Name  Marks
# 0  Ranjeet     44
# 1    Mukul     88
# 2    Sneha     79

# %%
ls2 = [['John',54],['Vinod',93]]
df2 = pd.DataFrame(ls2, columns=['Name','Marks'])
df2
# Out:
#     Name  Marks
# 0   John     54
# 1  Vinod     93

# %%
print(df1.shape)
print(df2.shape)
# Out:
# (3, 2)
# (2, 2)

# %%
ddf3 = df1.append(df2)
ddf3.index = list(range(0,5))
ddf3
# Out:
#       Name  Marks
# 0  Ranjeet     44
# 1    Mukul     88
# 2    Sneha     79
# 3     John     54
# 4    Vinod     93

# %%
ddf4 = df2.append(df1)
ddf4.index = list(range(0,5))
ddf4
# Out:
#       Name  Marks
# 0     John     54
# 1    Vinod     93
# 2  Ranjeet     44
# 3    Mukul     88
# 4    Sneha     79

# %%
ddf3.index
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %%
ddf3 = df1.append(df2)
ddf3.index=[0,1,2,3,4]  # list(ramge(0,5))
ddf3
# Out:
#       Name  Marks
# 0  Ranjeet     44
# 1    Mukul     88
# 2    Sneha     79
# 3     John     54
# 4    Vinod     93

# %%
df1
# Out:
#       Name  Marks
# 0  Ranjeet     44
# 1    Mukul     88
# 2    Sneha     79

# %%
df2
# Out:
#     Name  Marks
# 0   John     54
# 1  Vinod     93

# %%
ls3 = [['Vibhuti',60],['Molly',98]]
df3 = pd.DataFrame(ls3, columns=['Name','Age'])
df3
# Out:
#       Name  Age
# 0  Vibhuti   60
# 1    Molly   98

# %%
# df1 - Name, Marks
# df3 - Name, Age
t1 = df1.append(df3)
t1
# Out:
#       Name  Marks   Age
# 0  Ranjeet   44.0   NaN
# 1    Mukul   88.0   NaN
# 2    Sneha   79.0   NaN
# 0  Vibhuti    NaN  60.0
# 1    Molly    NaN  98.0

# %%
# df1 - Name, Marks
# df3 - Name, Age
t2 = df3.append(df1)
t2
# Out:
#       Name   Age  Marks
# 0  Vibhuti  60.0    NaN
# 1    Molly  98.0    NaN
# 0  Ranjeet   NaN   44.0
# 1    Mukul   NaN   88.0
# 2    Sneha   NaN   79.0

# %%
ls4 = [[38000,'45-Ashok Vihar'],[32000,'28-Noida']]
df4 = pd.DataFrame(ls4, columns=['Salary','Address'])
df4
# Out:
#    Salary         Address
# 0   38000  45-Ashok Vihar
# 1   32000        28-Noida

# %%
t3 = df1.append(df4)
t3
# Out:
#       Name  Marks   Salary         Address
# 0  Ranjeet   44.0      NaN             NaN
# 1    Mukul   88.0      NaN             NaN
# 2    Sneha   79.0      NaN             NaN
# 0      NaN    NaN  38000.0  45-Ashok Vihar
# 1      NaN    NaN  32000.0        28-Noida

# %%
t3.iloc[:5,[1,3]]
# Out:
#    Marks         Address
# 0   44.0             NaN
# 1   88.0             NaN
# 2   79.0             NaN
# 0    NaN  45-Ashok Vihar
# 1    NaN        28-Noida

# %%
t3.head()
# Out:
#       Name  Marks   Salary         Address
# 0  Ranjeet   44.0      NaN             NaN
# 1    Mukul   88.0      NaN             NaN
# 2    Sneha   79.0      NaN             NaN
# 0      NaN    NaN  38000.0  45-Ashok Vihar
# 1      NaN    NaN  32000.0        28-Noida

# %%
t3.iloc[1:4,0::2]
# Out:
#     Name   Salary
# 1  Mukul      NaN
# 2  Sneha      NaN
# 0    NaN  38000.0

# %%
t3.head()
# Out:
#       Name  Marks   Salary         Address
# 0  Ranjeet   44.0      NaN             NaN
# 1    Mukul   88.0      NaN             NaN
# 2    Sneha   79.0      NaN             NaN
# 0      NaN    NaN  38000.0  45-Ashok Vihar
# 1      NaN    NaN  32000.0        28-Noida

# %%
t3.loc[[0,1],['Name','Salary']]
# Out:
#       Name   Salary
# 0  Ranjeet      NaN
# 0      NaN  38000.0
# 1    Mukul      NaN
# 1      NaN  32000.0

# %% [markdown]
# ### Concat

# %%
d = {'Name':['Alisa','John','Cathrine','Marilyn','Rachael','Sebastian','Jacob','Rahul','David'],
     'Score1':[62,47,55,74,31,77,85,63,42],
     'Score2':[89,87,67,55,47,72,76,79,44],
     'Score3':[56,86,77,45,73,62,74,89,71]}
df1 = pd.DataFrame(d)
df1
# Out:
#         Name  Score1  Score2  Score3
# 0      Alisa      62      89      56
# 1       John      47      87      86
# 2   Cathrine      55      67      77
# 3    Marilyn      74      55      45
# 4    Rachael      31      47      73
# 5  Sebastian      77      72      62
# 6      Jacob      85      76      74
# 7      Rahul      63      79      89
# 8      David      42      44      71

# %%
d = {'Name':['Andrew','Ajay','Teresa'],
     'Score1':[32,71,57],
     'Score2':[92,99,69],
     'Score3':[67,97,68]}
df2 = pd.DataFrame(d)
df2
# Out:
#      Name  Score1  Score2  Score3
# 0  Andrew      32      92      67
# 1    Ajay      71      99      97
# 2  Teresa      57      69      68

# %%
w1 = pd.concat([df1,df2])
w1
# Out:
#         Name  Score1  Score2  Score3
# 0      Alisa      62      89      56
# 1       John      47      87      86
# 2   Cathrine      55      67      77
# 3    Marilyn      74      55      45
# 4    Rachael      31      47      73
# 5  Sebastian      77      72      62
# 6      Jacob      85      76      74
# 7      Rahul      63      79      89
# 8      David      42      44      71
# 0     Andrew      32      92      67
# 1       Ajay      71      99      97
# 2     Teresa      57      69      68

# %%
d = {
    'Name':['Jack','danny','vishwa'],
   'Score1':[32,71,70],
   'Score4':[72,91,89],
   'Score5':[57,72,78]}
 
df3 = pd.DataFrame(d)
df3
# Out:
#      Name  Score1  Score4  Score5
# 0    Jack      32      72      57
# 1   danny      71      91      72
# 2  vishwa      70      89      78

# %%
w2 = pd.concat([df1,df3]) 
w2
# Out:
#         Name  Score1  Score2  Score3  Score4  Score5
# 0      Alisa      62    89.0    56.0     NaN     NaN
# 1       John      47    87.0    86.0     NaN     NaN
# 2   Cathrine      55    67.0    77.0     NaN     NaN
# 3    Marilyn      74    55.0    45.0     NaN     NaN
# 4    Rachael      31    47.0    73.0     NaN     NaN
# 5  Sebastian      77    72.0    62.0     NaN     NaN
# 6      Jacob      85    76.0    74.0     NaN     NaN
# 7      Rahul      63    79.0    89.0     NaN     NaN
# 8      David      42    44.0    71.0     NaN     NaN
# 0       Jack      32     NaN     NaN    72.0    57.0
# 1      danny      71     NaN     NaN    91.0    72.0
# 2     vishwa      70     NaN     NaN    89.0    78.0

# %%
w3 = pd.concat([df1,df3],axis=1)
w3
# Out:
#         Name  Score1  Score2  Score3    Name  Score1  Score4  Score5
# 0      Alisa      62      89      56    Jack    32.0    72.0    57.0
# 1       John      47      87      86   danny    71.0    91.0    72.0
# 2   Cathrine      55      67      77  vishwa    70.0    89.0    78.0
# 3    Marilyn      74      55      45     NaN     NaN     NaN     NaN
# 4    Rachael      31      47      73     NaN     NaN     NaN     NaN
# 5  Sebastian      77      72      62     NaN     NaN     NaN     NaN
# 6      Jacob      85      76      74     NaN     NaN     NaN     NaN
# 7      Rahul      63      79      89     NaN     NaN     NaN     NaN
# 8      David      42      44      71     NaN     NaN     NaN     NaN

# %%
w3.columns
# Out:
# Index(['Name', 'Score1', 'Score2', 'Score3', 'Name', 'Score1', 'Score4',
#        'Score5'],
#       dtype='object')

# %%
w3['Name'][:3]
# Out:
#        Name    Name
# 0     Alisa    Jack
# 1      John   danny
# 2  Cathrine  vishwa

# %%
w3.loc[2:7,['Name','Score1','Score4']]
# Out:
#         Name    Name  Score1  Score1  Score4
# 2   Cathrine  vishwa      55    70.0    89.0
# 3    Marilyn     NaN      74     NaN     NaN
# 4    Rachael     NaN      31     NaN     NaN
# 5  Sebastian     NaN      77     NaN     NaN
# 6      Jacob     NaN      85     NaN     NaN
# 7      Rahul     NaN      63     NaN     NaN

# %%
w3.loc[2:7,'Name':'Score1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-122-4a393fe5ecdd> in <module>
# ----> 1 w3.loc[2:7,'Name':'Score1']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1067             return self._multi_take(tup)
#    1068
# -> 1069         return self._getitem_tuple_same_dim(tup)
#    1070
#    1071     def _get_label(self, label, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple_same_dim(self, tup)
#     773                 continue
#     774
# --> 775             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     776             # We should never have retval.ndim < self.ndim, as that should
#     777             #  be handled by the _getitem_lowerdim call above.
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1100         if isinstance(key, slice):
#    1101             self._validate_key(key, axis)
# -> 1102             return self._get_slice_axis(key, axis=axis)
#    1103         elif com.is_bool_indexer(key):
#    1104             return self._getbool_axis(key, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1134
#    1135         labels = obj._get_axis(axis)
# -> 1136         indexer = labels.slice_indexer(
#    1137             slice_obj.start, slice_obj.stop, slice_obj.step, kind="loc"
#    1138         )
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in slice_indexer(self, start, end, step, kind)
#    5275         slice(1, 3, None)
#    5276         """
# -> 5277         start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
#    5278
#    5279         # return a slice
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in slice_locs(self, start, end, step, kind)
#    5474         start_slice = None
#    5475         if start is not None:
# -> 5476             start_slice = self.get_slice_bound(start, "left", kind)
#    5477         if start_slice is None:
#    5478             start_slice = 0
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    5406                 )
#    5407             if isinstance(slc, np.ndarray):
# -> 5408                 raise KeyError(
#    5409                     f"Cannot get {side} slice bound for non-unique "
#    5410                     f"label: {repr(original_label)}"
#
# KeyError: "Cannot get left slice bound for non-unique label: 'Name'"

# %%
w3.iloc[2:6,:5]
# Out:
#         Name  Score1  Score2  Score3    Name
# 2   Cathrine      55      67      77  vishwa
# 3    Marilyn      74      55      45     NaN
# 4    Rachael      31      47      73     NaN
# 5  Sebastian      77      72      62     NaN

# %%
d = {
    'Name':['Jack','danny','vishwa'],
   'Score1':[32,71,70],
   'Score4':[72,91,89],
   'Score5':[57,72,78]}
 
df4 = pd.DataFrame(d)
df4
# Out:
#      Name  Score1  Score4  Score5
# 0    Jack      32      72      57
# 1   danny      71      91      72
# 2  vishwa      70      89      78

# %%
d1 = {'Score3':[56,86,77],
     'Score6':[78,89,93]}
df5 = pd.DataFrame(d1)
df5
# Out:
#    Score3  Score6
# 0      56      78
# 1      86      89
# 2      77      93

# %%
w5 = pd.concat([df4, df5], axis=1)
w5
# Out:
#      Name  Score1  Score4  Score5  Score3  Score6
# 0    Jack      32      72      57      56      78
# 1   danny      71      91      72      86      89
# 2  vishwa      70      89      78      77      93

# %%
w6 = pd.concat([df4, df5], axis=0)
w6.head()
# Out:
#      Name  Score1  Score4  Score5  Score3  Score6
# 0    Jack    32.0    72.0    57.0     NaN     NaN
# 1   danny    71.0    91.0    72.0     NaN     NaN
# 2  vishwa    70.0    89.0    78.0     NaN     NaN
# 0     NaN     NaN     NaN     NaN    56.0    78.0
# 1     NaN     NaN     NaN     NaN    86.0    89.0

# %%
pd.concat([df3, df4], axis=1)
# Out:
#      Name  Score1  Score4  Score5  Score3  Score6
# 0    Jack      32      72      57      56      78
# 1   danny      71      91      72      86      89
# 2  vishwa      70      89      78      77      93

# %% [markdown]
# ### Difference between concat and append
# 1) axis = 0 or axis = 1 can be used with concat but axis parameter is not available with append <br>
# 2) df.append() is equiivalent to pd.concat() along axis=0
