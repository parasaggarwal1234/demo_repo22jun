# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('houseprice.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
df.shape
# Out:
# (1460, 81)

# %%
df['Id'].nunique()
# Out:
# 1460

# %%
df.drop('Id',axis=1,inplace=True)
df.shape
# Out:
# (1460, 80)

# %%
nv = df.isnull().sum()
nv[nv>0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %%
df.drop(['PoolQC','Alley','MiscFeature'],axis=1,inplace=True)
nv = df.isnull().sum()
nv[nv>0]
# Out:
# LotFrontage      259
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# Fence           1179
# dtype: int64

# %%
cat_nan = [i for i in df.columns if df[i].isnull().sum()>0 and df[i].dtypes=='object']
num_nan = [i for i in df.columns if df[i].isnull().sum()>0 and df[i].dtypes!='object']
print(cat_nan)
print(len(cat_nan))
print(num_nan)
print(len(num_nan))
# Out:
# ['MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Electrical', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'Fence']
# 13
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']
# 3

# %% [markdown]
# #### Basement null value Handling

# %%
bs_cols = ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2']
for i in bs_cols:
    df[i].fillna('No_Base',inplace=True)
nv = df.isnull().sum()
nv[nv>0]
# Out:
# LotFrontage      259
# MasVnrType         8
# MasVnrArea         8
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# Fence           1179
# dtype: int64

# %%
gar_cols = ['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']
for i in gar_cols:
    df[i].fillna('No_Garage',inplace=True)
nv = df.isnull().sum()
nv[nv>0]
# Out:
# LotFrontage     259
# MasVnrType        8
# MasVnrArea        8
# Electrical        1
# FireplaceQu     690
# GarageYrBlt      81
# Fence          1179
# dtype: int64

# %%
for i in ['LotFrontage','MasVnrArea']:
    df[i].fillna(df[i].mean(),inplace=True)
nv = df.isnull().sum()
nv[nv>0]
# Out:
# MasVnrType        8
# Electrical        1
# FireplaceQu     690
# GarageYrBlt      81
# Fence          1179
# dtype: int64

# %%
nv = df.isnull().sum()
nv[nv>0]
# Out:
# MasVnrType        8
# Electrical        1
# FireplaceQu     690
# GarageYrBlt      81
# Fence          1179
# dtype: int64

# %%
for i in nv[nv>0].index:
    print(df[i].value_counts())
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64
# 2005.0    65
# 2006.0    59
# 2004.0    53
# 2003.0    50
# 2007.0    49
#           ..
# 1906.0     1
# 1908.0     1
# 1933.0     1
# 1900.0     1
# 1927.0     1
# Name: GarageYrBlt, Length: 97, dtype: int64
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: Fence, dtype: int64

# %%
nv[nv>0].index
# Out:
# Index(['MasVnrType', 'Electrical', 'FireplaceQu', 'GarageYrBlt', 'Fence'], dtype='object')

# %%
for i in ['MasVnrType', 'Electrical', 'FireplaceQu', 'Fence']:
    x = df[i].mode().max()
    df[i].fillna(x,inplace=True)

# %%
nv = df.isnull().sum()
nv[nv>0]
# Out:
# GarageYrBlt    81
# dtype: int64

# %%
df['GarageYrBlt'].fillna(2005.0,inplace=True)
nv = df.isnull().sum()
nv[nv>0]
# Out:
# Series([], dtype: int64)

# %%
df.shape
# Out:
# (1460, 77)

# %% [markdown]
# ### Outlier Handling

# %%
df.describe(percentiles=[0.97,0.98,0.99]).T
# Out:
#                 count           mean           std      min            50%  \
# MSSubClass     1460.0      56.897260     42.300571     20.0      50.000000
# LotFrontage    1460.0      70.049958     22.024023     21.0      70.049958
# LotArea        1460.0   10516.828082   9981.264932   1300.0    9478.500000
# OverallQual    1460.0       6.099315      1.382997      1.0       6.000000
# OverallCond    1460.0       5.575342      1.112799      1.0       5.000000
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1973.000000
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1994.000000
# MasVnrArea     1460.0     103.685262    180.569112      0.0       0.000000
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0     383.500000
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.000000
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     477.500000
# TotalBsmtSF    1460.0    1057.429452    438.705324      0.0     991.500000
# 1stFlrSF       1460.0    1162.626712    386.587738    334.0    1087.000000
# 2ndFlrSF       1460.0     346.992466    436.528436      0.0       0.000000
# LowQualFinSF   1460.0       5.844521     48.623081      0.0       0.000000
# GrLivArea      1460.0    1515.463699    525.480383    334.0    1464.000000
# BsmtFullBath   1460.0       0.425342      0.518911      0.0       0.000000
# BsmtHalfBath   1460.0       0.057534      0.238753      0.0       0.000000
# FullBath       1460.0       1.565068      0.550916      0.0       2.000000
# HalfBath       1460.0       0.382877      0.502885      0.0       0.000000
# BedroomAbvGr   1460.0       2.866438      0.815778      0.0       3.000000
# KitchenAbvGr   1460.0       1.046575      0.220338      0.0       1.000000
# TotRmsAbvGrd   1460.0       6.517808      1.625393      2.0       6.000000
# Fireplaces     1460.0       0.613014      0.644666      0.0       1.000000
# GarageYrBlt    1460.0    1979.976027     24.749688   1900.0    1984.500000
# GarageCars     1460.0       1.767123      0.747315      0.0       2.000000
# GarageArea     1460.0     472.980137    213.804841      0.0     480.000000
# WoodDeckSF     1460.0      94.244521    125.338794      0.0       0.000000
# OpenPorchSF    1460.0      46.660274     66.256028      0.0      25.000000
# EnclosedPorch  1460.0      21.954110     61.119149      0.0       0.000000
# 3SsnPorch      1460.0       3.409589     29.317331      0.0       0.000000
# ScreenPorch    1460.0      15.060959     55.757415      0.0       0.000000
# PoolArea       1460.0       2.758904     40.177307      0.0       0.000000
# MiscVal        1460.0      43.489041    496.123024      0.0       0.000000
# MoSold         1460.0       6.321918      2.703626      1.0       6.000000
# YrSold         1460.0    2007.815753      1.328095   2006.0    2008.000000
# SalePrice      1460.0  180921.195890  79442.502883  34900.0  163000.000000
#
#                      97%        98%        99%       max
# MSSubClass        160.00     188.20     190.00     190.0
# LotFrontage       114.00     120.82     137.41     313.0
# LotArea         21571.80   25251.62   37567.64  215245.0
# OverallQual         9.00       9.00      10.00      10.0
# OverallCond         8.00       8.00       9.00       9.0
# YearBuilt        2007.00    2008.00    2009.00    2010.0
# YearRemodAdd     2008.00    2008.00    2009.00    2010.0
# MasVnrArea        573.69     650.82     791.28    1600.0
# BsmtFinSF1       1375.99    1442.64    1572.41    5644.0
# BsmtFinSF2        546.23     658.12     830.38    1474.0
# BsmtUnfSF        1589.38    1678.20    1797.05    2336.0
# TotalBsmtSF      1905.46    2001.64    2155.05    6110.0
# 1stFlrSF         1981.61    2072.28    2219.46    4692.0
# 2ndFlrSF         1245.53    1318.56    1418.92    2065.0
# LowQualFinSF        0.00       0.00     360.00     572.0
# GrLivArea        2633.23    2782.38    3123.48    5642.0
# BsmtFullBath        1.00       1.00       2.00       3.0
# BsmtHalfBath        1.00       1.00       1.00       2.0
# FullBath            2.00       3.00       3.00       3.0
# HalfBath            1.00       1.00       1.00       2.0
# BedroomAbvGr        4.00       4.00       5.00       8.0
# KitchenAbvGr        2.00       2.00       2.00       3.0
# TotRmsAbvGrd       10.00      10.82      11.00      14.0
# Fireplaces          2.00       2.00       2.00       3.0
# GarageYrBlt      2008.00    2008.00    2009.00    2010.0
# GarageCars          3.00       3.00       3.00       4.0
# GarageArea        884.00     907.46    1002.79    1418.0
# WoodDeckSF        385.38     430.10     505.46     857.0
# OpenPorchSF       213.23     240.82     285.82     547.0
# EnclosedPorch     216.00     235.64     261.05     552.0
# 3SsnPorch           0.00       0.00     168.00     508.0
# ScreenPorch       192.00     223.64     268.05     480.0
# PoolArea            0.00       0.00       0.00     738.0
# MiscVal           400.00     500.00     700.00   15500.0
# MoSold             12.00      12.00      12.00      12.0
# YrSold           2010.00    2010.00    2010.00    2010.0
# SalePrice      374230.00  394931.06  442567.01  755000.0

# %%
df.describe(percentiles=[0.97,0.98,0.99]).T.index
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
out_cols_98 = ['LotFrontage','LotArea','MasVnrArea','BsmtFinSF1','BsmtFinSF2',
               'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
              'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'HalfBath',
              'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
               'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
              'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
               'SalePrice']
print(out_cols_98)
# Out:
# ['LotFrontage', 'LotArea', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'SalePrice']

# %%
def oh1(x):
    x = x.clip(upper=x.quantile(0.98))
    return x

# %%
df[out_cols_98] = df[out_cols_98].apply(oh1)

# %%
df.describe(percentiles=[0.01,0.02,0.03,0.05]).T
# Out:
#                 count           mean           std      min        1%  \
# MSSubClass     1460.0      56.897260     42.300571     20.0     20.00
# LotFrontage    1460.0      69.405164     18.845067     21.0     21.00
# LotArea        1460.0    9884.318219   4269.103743   1300.0   1680.00
# OverallQual    1460.0       6.099315      1.382997      1.0      3.00
# OverallCond    1460.0       5.575342      1.112799      1.0      3.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0   1899.18
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0   1950.00
# MasVnrArea     1460.0      99.054851    159.552455      0.0      0.00
# BsmtFinSF1     1460.0     436.678219    424.424497      0.0      0.00
# BsmtFinSF2     1460.0      41.938082    136.258146      0.0      0.00
# BsmtUnfSF      1460.0     563.631507    431.331047      0.0      0.00
# TotalBsmtSF    1460.0    1048.256986    398.396991      0.0      0.00
# 1stFlrSF       1460.0    1155.655068    358.974939    334.0    520.00
# 2ndFlrSF       1460.0     343.673151    427.613429      0.0      0.00
# LowQualFinSF   1460.0       0.000000      0.000000      0.0      0.00
# GrLivArea      1460.0    1504.468767    483.292715    334.0    692.18
# BsmtFullBath   1460.0       0.413699      0.492665      0.0      0.00
# BsmtHalfBath   1460.0       0.056164      0.230318      0.0      0.00
# FullBath       1460.0       1.565068      0.550916      0.0      1.00
# HalfBath       1460.0       0.374658      0.484200      0.0      0.00
# BedroomAbvGr   1460.0       2.839726      0.748082      0.0      1.00
# KitchenAbvGr   1460.0       1.045205      0.211098      0.0      1.00
# TotRmsAbvGrd   1460.0       6.504521      1.584136      2.0      3.00
# Fireplaces     1460.0       0.609589      0.634547      0.0      0.00
# GarageYrBlt    1460.0    1979.976027     24.749688   1900.0   1917.18
# GarageCars     1460.0       1.763699      0.739318      0.0      0.00
# GarageArea     1460.0     470.137534    205.938812      0.0      0.00
# WoodDeckSF     1460.0      92.019178    117.263208      0.0      0.00
# OpenPorchSF    1460.0      45.170959     59.666175      0.0      0.00
# EnclosedPorch  1460.0      21.067260     56.943392      0.0      0.00
# 3SsnPorch      1460.0       0.000000      0.000000      0.0      0.00
# ScreenPorch    1460.0      13.677534     48.367922      0.0      0.00
# PoolArea       1460.0       0.000000      0.000000      0.0      0.00
# MiscVal        1460.0      16.482192     86.867615      0.0      0.00
# MoSold         1460.0       6.321918      2.703626      1.0      1.00
# YrSold         1460.0    2007.815753      1.328095   2006.0   2006.00
# SalePrice      1460.0  179093.495753  71929.291417  34900.0  61815.97
#
#                      2%        3%        5%            50%        max
# MSSubClass        20.00     20.00     20.00      50.000000     190.00
# LotFrontage       24.00     30.00     35.95      70.049958     120.82
# LotArea         2124.74   2522.00   3311.70    9478.500000   25251.62
# OverallQual        4.00      4.00      4.00       6.000000      10.00
# OverallCond        3.00      4.00      4.00       5.000000       9.00
# YearBuilt       1908.36   1910.00   1916.00    1973.000000    2010.00
# YearRemodAdd    1950.00   1950.00   1950.00    1994.000000    2010.00
# MasVnrArea         0.00      0.00      0.00       0.000000     650.82
# BsmtFinSF1         0.00      0.00      0.00     383.500000    1442.64
# BsmtFinSF2         0.00      0.00      0.00       0.000000     658.12
# BsmtUnfSF          0.00      0.00      0.00     477.500000    1678.20
# TotalBsmtSF        0.00    312.33    519.30     991.500000    2001.64
# 1stFlrSF         583.70    625.00    672.95    1087.000000    2072.28
# 2ndFlrSF           0.00      0.00      0.00       0.000000    1318.56
# LowQualFinSF       0.00      0.00      0.00       0.000000       0.00
# GrLivArea        768.00    796.00    848.00    1464.000000    2782.38
# BsmtFullBath       0.00      0.00      0.00       0.000000       1.00
# BsmtHalfBath       0.00      0.00      0.00       0.000000       1.00
# FullBath           1.00      1.00      1.00       2.000000       3.00
# HalfBath           0.00      0.00      0.00       0.000000       1.00
# BedroomAbvGr       1.00      1.00      2.00       3.000000       4.00
# KitchenAbvGr       1.00      1.00      1.00       1.000000       2.00
# TotRmsAbvGrd       4.00      4.00      4.00       6.000000      10.82
# Fireplaces         0.00      0.00      0.00       1.000000       2.00
# GarageYrBlt     1920.00   1924.00   1930.00    1984.500000    2010.00
# GarageCars         0.00      0.00      0.00       2.000000       3.00
# GarageArea         0.00      0.00      0.00     480.000000     907.46
# WoodDeckSF         0.00      0.00      0.00       0.000000     430.10
# OpenPorchSF        0.00      0.00      0.00      25.000000     240.82
# EnclosedPorch      0.00      0.00      0.00       0.000000     235.64
# 3SsnPorch          0.00      0.00      0.00       0.000000       0.00
# ScreenPorch        0.00      0.00      0.00       0.000000     223.64
# PoolArea           0.00      0.00      0.00       0.000000       0.00
# MiscVal            0.00      0.00      0.00       0.000000     500.00
# MoSold             1.00      1.00      2.00       6.000000      12.00
# YrSold          2006.00   2006.00   2006.00    2008.000000    2010.00
# SalePrice      79000.00  82000.00  88000.00  163000.000000  394931.06

# %%
out_cols_01 = ['LotArea', 'OverallQual', 'OverallCond','1stFlrSF','TotRmsAbvGrd',
                'GrLivArea','SalePrice']
print(out_cols_01)
# Out:
# ['LotArea', 'OverallQual', 'OverallCond', '1stFlrSF', 'TotRmsAbvGrd', 'GrLivArea', 'SalePrice']

# %%
def oh2(x):
    x = x.clip(lower=x.quantile(0.01))
    return x

# %%
df[out_cols_01] = df[out_cols_01].apply(oh2)

# %%
df.shape
# Out:
# (1460, 77)

# %%
df1 = df.copy()
df1.shape
# Out:
# (1460, 77)

# %%
cat_cols = [i for i in df.columns if df[i].dtypes=='object']
print(len(cat_cols))
# Out:
# 40

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
for i in cat_cols:
    df1[i] = lb.fit_transform(df1[i])
df1.dtypes.value_counts()
# Out:
# int32      40
# int64      19
# float64    18
# dtype: int64

# %%
x = df1.drop('SalePrice',axis=1)
y = df1['SalePrice']
print(x.shape)
print(y.shape)
# Out:
# (1460, 76)
# (1460,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1095, 76)
# (365, 76)
# (1095,)
# (365,)

# %%
m1 = LinearRegression()
m1.fit(x_train,y_train)
print('Training_score',m1.score(x_train,y_train))
print('Testing_score',m1.score(x_test,y_test))
# Out:
# Training_score 0.8975795484903208
# Testing_score 0.8775319555943935

# %%
sc = StandardScaler()
x_train_sc = sc.fit_transform(x_train) 
x_test_sc = sc.fit_transform(x_test) 
# x_train_sc = x_train_sc.transform(x_train) 
# x_test_sc = sc.fit(x_test) 
# x_test_sc = x_test_sc.transform(x_test)
# print(x_train_sc.shape)
# print(x_test_sc.shape)

# %%
m1 = LinearRegression()
m1.fit(x_train_sc,y_train)
print('Training_score',m1.score(x_train_sc,y_train))
print('Testing_score',m1.score(x_test_sc,y_test))
# Out:
# Training_score 0.8975793601076862
# Testing_score 0.8703350703302973

# %%
sc = StandardScaler()
x_train_sc = sc.fit(x_train) 
x_train_sc = x_train_sc.transform(x_train) 
x_test_sc = sc.fit(x_test) 
x_test_sc = x_test_sc.transform(x_test)
print(x_train_sc.shape)
print(x_test_sc.shape)
# Out:
# (1095, 76)
# (365, 76)

# %%
m1 = LinearRegression()
m1.fit(x_train_sc,y_train)
print('Training_score',m1.score(x_train_sc,y_train))
print('Testing_score',m1.score(x_test_sc,y_test))
# Out:
# Training_score 0.8975793601076862
# Testing_score 0.8703350703302973

# %% [markdown]
# #### PCA

# %%
pca1 = PCA()
pc_x_train = pca1.fit_transform(x_train_sc)
pc_x_test = pca1.transform(x_test_sc)
print(pc_x_train.shape)
print(pc_x_test.shape)
# Out:
# (1095, 76)
# (365, 76)

# %%
eig_val = pd.DataFrame({'Var':pca1.explained_variance_})
eig_val.head()
# Out:
#          Var
# 0  10.384868
# 1   4.197843
# 2   3.746480
# 3   3.140968
# 4   2.361428

# %%
eig_val['Contri'] = eig_val['Var']*100/eig_val['Var'].sum()
eig_val['CumSum'] = eig_val['Contri'].cumsum()
eig_val.head()
# Out:
#          Var     Contri     CumSum
# 0  10.384868  14.212856  14.212856
# 1   4.197843   5.745219  19.958075
# 2   3.746480   5.127477  25.085551
# 3   3.140968   4.298766  29.384318
# 4   2.361428   3.231879  32.616197

# %%
eig_val[eig_val['CumSum']<80].tail(7)
# Out:
#          Var    Contri     CumSum
# 27  0.884707  1.210821  72.916390
# 28  0.853366  1.167927  74.084317
# 29  0.842906  1.153611  75.237928
# 30  0.830766  1.136996  76.374924
# 31  0.800538  1.095625  77.470550
# 32  0.784583  1.073790  78.544340
# 33  0.776902  1.063277  79.607617

# %%
pc_train = pd.DataFrame(pc_x_train)
pc_train = pc_train.iloc[:,:30]
print(pc_train.shape)
pc_train.head()
# Out:
# (1095, 30)
#          0         1         2         3         4         5         6   \
# 0 -2.989308  0.976813 -0.846649  0.292327 -1.702240 -0.345838 -0.420542
# 1 -1.791703  2.038240 -0.939618  0.295328 -1.503408  0.792044 -1.746281
# 2  3.296313  0.058509  3.282697 -0.402919  1.958097 -1.648124 -2.627722
# 3  5.982496  0.521640 -0.724527  0.266458  1.412489  1.258754 -0.883326
# 4  8.013230  0.967727  0.891592  0.864830  3.434425 -0.611202 -2.370068
#
#          7         8         9   ...        20        21        22        23  \
# 0  0.655139 -1.293456  0.158067  ... -0.442029  0.328269 -1.813065  0.541405
# 1  2.197920 -0.929943 -0.320377  ...  0.269205 -0.124805 -0.762342  0.117262
# 2  0.152366  1.479858 -0.467454  ...  0.612104 -0.039307  0.205956 -1.511367
# 3  0.676762  0.064002 -2.216966  ... -1.323492  0.464534 -0.263541  0.887727
# 4  0.367729  0.819353 -0.672292  ... -0.810315  0.628391  0.745845  1.146182
#
#          24        25        26        27        28        29
# 0 -0.068698 -0.460453  0.679631  0.874045 -0.565088 -0.949712
# 1 -0.617770 -0.048640  0.469441  0.986523 -0.210479  0.751252
# 2  0.698742 -1.046994  0.040986 -0.182745  0.924314  1.594990
# 3  0.482176 -1.009214  0.378742  0.661886 -0.146480  1.225249
# 4  1.492018 -0.897606  0.233381 -2.357366 -0.094642 -0.236181
#
# [5 rows x 30 columns]

# %%
pc_test = pd.DataFrame(pc_x_test)
pc_test = pc_test.iloc[:,:30]
print(pc_test.shape)
pc_test.head()
# Out:
# (365, 30)
#          0         1         2         3         4         5         6   \
# 0  1.330850 -0.293743 -1.862090 -2.574635 -1.832428 -0.684018  0.643035
# 1  3.016077 -0.889899  0.828192 -1.664885 -0.190440 -0.423672 -0.063394
# 2  1.908798 -2.172842 -3.150334 -0.961047  0.958583 -2.102296  0.535765
# 3  2.702761 -1.864979 -4.048003 -1.390491 -0.090056 -0.856518  0.588510
# 4  6.998859 -1.641952  0.904600 -2.619936  2.349754  0.423656 -1.404924
#
#          7         8         9   ...        20        21        22        23  \
# 0  0.286528 -0.395829  0.266550  ... -1.250416 -0.417997  0.343258 -0.169070
# 1 -0.462595  0.350169 -1.471485  ...  0.365406 -0.481160 -0.502337 -0.947816
# 2  0.745557  1.048587  1.725041  ...  0.275067 -0.792586 -0.467624 -0.700932
# 3  0.748826 -2.916430  1.514294  ... -0.107085  0.302479  0.356842 -1.020620
# 4  0.694940 -0.468636 -1.326026  ... -0.818536 -0.084805 -0.526003  0.265893
#
#          24        25        26        27        28        29
# 0  0.086213 -0.251043 -0.200621  1.097640 -0.197166 -0.090281
# 1  0.145588 -0.220981 -0.041957 -0.768075  0.986858 -0.537813
# 2 -0.860776  1.812595 -0.841202 -0.256301  0.368162  0.296490
# 3  0.825513 -0.322551  0.182413  0.495506 -0.516911 -0.276981
# 4 -0.023249  0.468795 -0.646781  0.089613 -0.269265 -0.347571
#
# [5 rows x 30 columns]

# %%
print(pc_train.shape)
print(pc_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1095, 30)
# (365, 30)
# (1095,)
# (365,)

# %%
m1 = LinearRegression()
m1.fit(pc_train,y_train)
print('Training_score',m1.score(pc_train,y_train))
print('Testing_score',m1.score(pc_test,y_test))
# Out:
# Training_score 0.8747690383150638
# Testing_score 0.854233928966726

# %% [markdown]
# ### Get_Dummies

# %%
cat_cols = [i for i in df.columns if df[i].dtypes=='object']
print(len(cat_cols))
print(cat_cols)
# Out:
# 40
# ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'Fence', 'SaleType', 'SaleCondition']

# %%
df1 = pd.get_dummies(data=df,columns=cat_cols,drop_first=True)
df1.shape
# Out:
# (1460, 249)

# %%
x = df1.drop('SalePrice',axis=1)
y = df1['SalePrice']
print(x.shape)
print(y.shape)
# Out:
# (1460, 248)
# (1460,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
fit = sc.fit(x)
x_sc = fit.transform(x)
print(x_sc.shape)
# Out:
# (1460, 248)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_sc,y,test_size=0.25)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1095, 248)
# (365, 248)
# (1095,)
# (365,)

# %%
m1 = LinearRegression()
m1.fit(x_train,y_train)
print('Training_score',m1.score(x_train,y_train))
print('Testing_score',m1.score(x_test,y_test))
# Out:
# Training_score 0.9446589268956738
# Testing_score -1.0834243583654046e+21

# %% [markdown]
# ### PCA from skelarn

# %%
from sklearn.decomposition import PCA

# %%
pca1 = PCA()
pc1 = pca1.fit(x_sc)
pc1 = pc1.transform(x_sc)
print(pc1.shape)
# Out:
# (1460, 248)

# %%
eig_val1 = pd.DataFrame({'Var':pca1.explained_variance_})
eig_val1.head()
# Out:
#          Var
# 0  16.889245
# 1   8.089807
# 2   7.198392
# 3   5.890462
# 4   5.542149

# %%
eig_val1['Contri'] = eig_val1['Var']*100/eig_val1['Var'].sum()
eig_val1.head()
# Out:
#          Var    Contri
# 0  16.889245  6.888848
# 1   8.089807  3.299700
# 2   7.198392  2.936107
# 3   5.890462  2.402624
# 4   5.542149  2.260552

# %%
eig_val1['CumSum'] = eig_val1['Contri'].cumsum()
eig_val1.tail()
# Out:
#               Var        Contri  CumSum
# 243  6.048291e-32  2.466999e-32   100.0
# 244  6.048291e-32  2.466999e-32   100.0
# 245  6.048291e-32  2.466999e-32   100.0
# 246  4.627411e-32  1.887445e-32   100.0
# 247  2.643455e-32  1.078222e-32   100.0

# %%
eig_val1[eig_val1['CumSum']<76].tail()
# Out:
#          Var    Contri     CumSum
# 83  1.019021  0.415642  74.251955
# 84  1.009164  0.411621  74.663576
# 85  1.002222  0.408790  75.072366
# 86  0.993842  0.405372  75.477738
# 87  0.978277  0.399023  75.876761

# %%
res_df = pd.DataFrame(pc1)
res_df.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -4.464266  1.864573 -0.442591 -0.198390 -1.442747 -2.064312 -0.583703
# 1 -0.102440 -3.101643  0.375792 -1.028276  0.580757 -0.839022  0.912768
# 2 -5.152943  1.075597  0.064882  0.333054 -0.703609 -2.513562  0.007636
# 3  1.317366  0.372536 -0.794489  2.993878 -0.539634  0.981081  0.865942
# 4 -6.891859  0.377635  0.802507  2.566966  0.745329 -3.065300 -0.449504
#
#         7         8         9    ...       238           239           240  \
# 0 -1.332883  1.683657 -0.987843  ...  0.001264  1.746938e-15 -3.833133e-16
# 1 -1.174784 -0.263074 -0.199181  ...  0.043600 -2.176509e-17  1.673960e-16
# 2 -1.981288  1.815666 -0.791633  ... -0.013865 -1.432877e-15  1.341544e-16
# 3 -0.852970 -0.922942 -1.604405  ...  0.003966 -6.209334e-16  2.965726e-16
# 4 -0.834175  2.748574 -0.930788  ... -0.003807  1.050813e-15 -2.513606e-16
#
#             241           242           243           244           245  \
# 0 -2.503281e-16  2.785685e-16  9.759917e-17  3.225347e-16 -3.264428e-17
# 1  9.943667e-17 -8.860665e-17 -2.611317e-16 -2.570838e-16  2.892276e-16
# 2 -2.517090e-16 -1.893685e-16 -3.979395e-17 -9.825584e-17  2.534489e-17
# 3  5.047826e-16 -1.318774e-16  7.755787e-17 -1.530063e-16 -7.167035e-17
# 4 -4.058885e-16 -2.831473e-16 -2.128887e-16  5.784383e-16 -2.143634e-16
#
#             246           247
# 0  3.698753e-17  8.533404e-17
# 1  2.017975e-16 -1.567469e-16
# 2  8.476779e-17  6.272710e-17
# 3  9.579173e-19 -2.465010e-16
# 4 -2.689726e-16  2.418104e-16
#
# [5 rows x 248 columns]

# %%
x_reg = res_df.iloc[:,:86]

y_reg = y
print(x_reg.shape)
print(y_reg.shape)
# Out:
# (1460, 86)
# (1460,)

# %%
from sklearn.model_selection import train_test_split
x_train1,x_test1,y_train1,y_test1 = train_test_split(x_reg,y_reg,test_size=0.25)
print(x_train1.shape)
print(x_test1.shape)
print(y_train1.shape)
print(y_test1.shape)
# Out:
# (1095, 86)
# (365, 86)
# (1095,)
# (365,)

# %%
from sklearn.linear_model import LinearRegression

# %%
m1 = LinearRegression()
m1.fit(x_train1,y_train1)
print('Training_score',m1.score(x_train1,y_train1))
print('Testing_score',m1.score(x_test1,y_test1))
# Out:
# Training_score 0.8936064015085051
# Testing_score 0.818911813985381

# %%
ypred = m1.predict(x_test1)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
mae = mean_absolute_error(y_test1,ypred)
mse = mean_squared_error(y_test1,ypred)
rmse = mean_squared_error(y_test1,ypred,squared=False)
r2s = r2_score(y_test1,ypred)
print('MAE',mae)
print('MSE',mse)
print('RMSE',rmse)
print('R2_Score',r2s)
# Out:
# MAE 19510.906430757314
# MSE 935988060.7579399
# RMSE 30593.921957767034
# R2_Score 0.818911813985381

# %%
print(x_reg.shape)
# Out:
# (1460, 86)

# %%
x_reg.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -4.464266  1.864573 -0.442591 -0.198390 -1.442747 -2.064312 -0.583703
# 1 -0.102440 -3.101643  0.375792 -1.028276  0.580757 -0.839022  0.912768
# 2 -5.152943  1.075597  0.064882  0.333054 -0.703609 -2.513562  0.007636
# 3  1.317366  0.372536 -0.794489  2.993878 -0.539634  0.981081  0.865942
# 4 -6.891859  0.377635  0.802507  2.566966  0.745329 -3.065300 -0.449504
#
#          7         8         9   ...        76        77        78        79  \
# 0 -1.332883  1.683657 -0.987843  ...  0.107887  0.029752  0.307942 -0.436308
# 1 -1.174784 -0.263074 -0.199181  ... -0.528393 -1.528359 -0.113512  0.664872
# 2 -1.981288  1.815666 -0.791633  ...  0.395511 -0.322894 -0.159934 -0.035286
# 3 -0.852970 -0.922942 -1.604405  ...  0.986687  0.681804  0.447326 -0.578144
# 4 -0.834175  2.748574 -0.930788  ... -0.791224  0.296559  0.169668 -0.455452
#
#          80        81        82        83        84        85
# 0  0.570690  0.112625  0.176048 -0.463447  0.078269  0.107281
# 1  1.226447  1.842406  1.228580  1.487395 -0.957590  0.764585
# 2 -0.757463 -0.276181 -0.098577 -0.188813 -0.519777  0.302030
# 3  0.355476  0.932366  0.149926 -1.283881  1.490924 -0.246296
# 4 -1.195222  0.959332  0.948420  0.375732  1.178538 -0.336009
#
# [5 rows x 86 columns]

# %%
t = []
s = 'PC'   # PC = Principal component
for i in range(x_reg.shape[1]):  # x_reg.shape =(1460,86)  # i=0,1,2,3,.....,85
    d = s + str(i)
    t.append(d)
print(t)
# Out:
# ['PC0', 'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8', 'PC9', 'PC10', 'PC11', 'PC12', 'PC13', 'PC14', 'PC15', 'PC16', 'PC17', 'PC18', 'PC19', 'PC20', 'PC21', 'PC22', 'PC23', 'PC24', 'PC25', 'PC26', 'PC27', 'PC28', 'PC29', 'PC30', 'PC31', 'PC32', 'PC33', 'PC34', 'PC35', 'PC36', 'PC37', 'PC38', 'PC39', 'PC40', 'PC41', 'PC42', 'PC43', 'PC44', 'PC45', 'PC46', 'PC47', 'PC48', 'PC49', 'PC50', 'PC51', 'PC52', 'PC53', 'PC54', 'PC55', 'PC56', 'PC57', 'PC58', 'PC59', 'PC60', 'PC61', 'PC62', 'PC63', 'PC64', 'PC65', 'PC66', 'PC67', 'PC68', 'PC69', 'PC70', 'PC71', 'PC72', 'PC73', 'PC74', 'PC75', 'PC76', 'PC77', 'PC78', 'PC79', 'PC80', 'PC81', 'PC82', 'PC83', 'PC84', 'PC85']

# %%
x_reg.columns = t
x_reg.head()
# Out:
#         PC0       PC1       PC2       PC3       PC4       PC5       PC6  \
# 0 -4.464266  1.864573 -0.442591 -0.198390 -1.442747 -2.064312 -0.583703
# 1 -0.102440 -3.101643  0.375792 -1.028276  0.580757 -0.839022  0.912768
# 2 -5.152943  1.075597  0.064882  0.333054 -0.703609 -2.513562  0.007636
# 3  1.317366  0.372536 -0.794489  2.993878 -0.539634  0.981081  0.865942
# 4 -6.891859  0.377635  0.802507  2.566966  0.745329 -3.065300 -0.449504
#
#         PC7       PC8       PC9  ...      PC76      PC77      PC78      PC79  \
# 0 -1.332883  1.683657 -0.987843  ...  0.107887  0.029752  0.307942 -0.436308
# 1 -1.174784 -0.263074 -0.199181  ... -0.528393 -1.528359 -0.113512  0.664872
# 2 -1.981288  1.815666 -0.791633  ...  0.395511 -0.322894 -0.159934 -0.035286
# 3 -0.852970 -0.922942 -1.604405  ...  0.986687  0.681804  0.447326 -0.578144
# 4 -0.834175  2.748574 -0.930788  ... -0.791224  0.296559  0.169668 -0.455452
#
#        PC80      PC81      PC82      PC83      PC84      PC85
# 0  0.570690  0.112625  0.176048 -0.463447  0.078269  0.107281
# 1  1.226447  1.842406  1.228580  1.487395 -0.957590  0.764585
# 2 -0.757463 -0.276181 -0.098577 -0.188813 -0.519777  0.302030
# 3  0.355476  0.932366  0.149926 -1.283881  1.490924 -0.246296
# 4 -1.195222  0.959332  0.948420  0.375732  1.178538 -0.336009
#
# [5 rows x 86 columns]

# %% [markdown]
# #### Applying Regresion on Stanradized data

# %%
# x_sc
x_train2,x_test2,y_train2,y_test2 = train_test_split(x_sc,y_reg,test_size=0.25,random_state=25)
print(x_train2.shape)
print(x_test2.shape)
print(y_train2.shape)
print(y_test2.shape)
# Out:
# (1095, 248)
# (365, 248)
# (1095,)
# (365,)

# %%
from sklearn.model_selection import KFold,cross_val_score

# %%
kf = KFold(n_splits=20)
model = LinearRegression()
scores = cross_val_score(model,x_train2,y_train2,scoring='r2',cv=kf)
print(scores)
print(scores.mean())
# Out:
# [-3.58362890e+15 -1.91291128e+17  9.42444143e-01 -1.12967003e+20
#  -7.09708432e+18  8.05075611e-01 -4.73460335e+22 -3.78629680e+18
#  -1.80597322e+22 -4.14769567e+20 -3.73277400e+07 -8.16632053e+17
#  -1.34736601e+12  8.24177073e-01  8.50513737e-01  8.10723730e-01
#  -7.82189140e+18 -8.86510683e+20 -2.60568164e+16  8.95779244e-01]
# -3.3419877928581375e+21

# %%
m2 = LinearRegression()
m2.fit(x_train2,y_train2)
print('Training_score',m2.score(x_train2,y_train2))
print('Testing_score',m2.score(x_test2,y_test2))
# Out:
# Training_score 0.9440035745259744
# Testing_score -6.685557423422256e+21
