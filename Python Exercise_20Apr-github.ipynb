# %% [markdown]
# ### Exercise
#
# #### Q1)
# WAF to check if a number is prime or not. The number (int) is passed as an argument<br>
# Function call<br>
# prime_check(17)<br>
# prime_check(24)<br>
#
# Sample Output<br>
# Prime<br>
# Not Prime
#
# #### Q2)
# WAF to print all the prime numbers between two numbers (n1,n2). <br>
# The numbers (n1,n2) are passed as an argument<br>
# Function call<br>
# prime_between(50,20)<br>
# prime_between(24,40)<br>
# Sample Output<br>
# [23, 29, 31, 37, 41, 43, 47]<br>
# [29, 31, 37]
#
# #### Q3)
# Find the sports that are played indoor from the tuple given below.<br>
# sports = (('Chess','indoor'),
# ('Cricket', 'Outdoor'),
# ('Carrom','indoOr'),
# ('Badminton','Indoor'),
# ('Football','Outdoor'),
# ('Darts','iNdoor'),
# ('Swimming','Outdoor'),
# ('Trampoline','Indoor'))
#
# Sample Output<br>
# Sample Indoor: ['Chess', 'Carrom', 'Badminton', 'Darts', 'Trampoline']-
#
# #### Q4)
# Write a function to reverse a string. The string is passed as an argument.<br>
# string_rev('Python')<br>
# Sample Output<br>
# nohtyP<br>
#
#
# #### Q5)
# A list of words is given. Convert the words into uppercase. Use lambda and map functions.<br>
# words = ['inDia','NepaL','AuStraLia','IrEland','jaPAn','egypt']<br>
# Output<br>
# ['INDIA', 'NEPAL', 'AUSTRALIA', 'IRELAND', 'JAPAN', 'EGYPT']
#
# #### Q6)
# Write a program to extract the words from the given list which have their first character in uppercase.<br>
# Days = ['Laptop', 'desktop','mobile', 'Smartwatch', 'Drones'] <br>
# Output: ['Laptop', 'SmartWatch', 'Drones']<br>
#
# #### Q7)
# A list of words is given. Find the words from the list that have their
# fifth character in uppercase.<br>
# ls = ['welcOme', 'world', 'cosmOs', 'moviEs', 'reFlection']
# Output: ['welcOme', 'cosmOs','moviEs']
#
# #### Q8)
# Write a program swap the keys to values and values to keys in the given dictionary.<br>
# Course = {'Tableau':10,'Java':20, 'Azure':35, 'AWS':45,'Kubernetes':55} <br>
# Output: {10:'Tableau',20:'Java', 35:'Azure', 45:'AWS',55:'Kubernetes'}
#
# #### Q9)
# Write a function to print k prime numbers smaller than a given number n
# k and n are integers where k<n. Also k is less than number of total prime numbers less than n<br>
# kprime_less_than_n(7,78)
# Sample Output<br>
# [47, 53, 59, 61, 67, 71, 73]
#
# #### Q10)
# Write a function to print k prime numbers greater than a given number n.<br>
# k and n are integers where k<n.<br>
# kprime_greater_than_n(7,78)<br>
# Sample Output<br>
# [79, 83, 89, 97, 101, 103, 107]
#
#
# #### Q11)
# Define a function to check whether a number is in a range (500,50000) or not.<br>
# Sample Input<br>
# -230<br>
# 3487<br>
# Sample Output<br>
# Out of Range<br>
# In Range<br>
#
# #### Q12)
# Write a program to calculate the sum  and average of all elements in the list.<br>
# marks = [78,56,85,67,93,80,58]<br>
# Sample Output<br>
# Sum : 517<br>
# Avg : 73.86
#
# #### Q13)
# Replace all the odd numbers in the list with -1<br>
# r = [23,34,45,56,67,78,89,12,15,57,38]<br>
# Output<br>
# [-1,34,-1,56,-1,78,-1,-1,12,-1,-1,38]
#
# #### Q14)
# Write a function to check if the number is armstrong number of not<br>
# Sample Input<br>
# 153<br>
# 345<br>
# Sample Output<br>
# Armstrong<br>
# Not Armstrong<br>
#
# #### Q15)
# A list of dates (dd-mm-yyyy) in the form of string is given below.
# Create a new list that stores years i.e. the 'yyyy' part from the dates in
# the given list.<br>
# datesList = ['23-10-2001','04-03-2010','12-06-2019','28-12-2021']<br>
# Output: ['2001','2010','2019','2021']<br>
#
# #### Q16)
# Write a function to check if the number is palindrome number of not<br>
# Sample Input<br>
# 12321<br>
# 8732432<br>
# Sample Output<br>
# Palindrome<br>
# Not Palindrome<br>
#
# #### Q17)
# Create a dictionary containing 4 lambda functions using x as lambda parameter
# <br>
# a) (2x)-3  b) x^2 + 5 c) x^(0.5)-5 d) x^3 + 1
#
# E.g. dict = {'Expression1': function for computing 2x-3-, 'Expression2': function for computing x^2+3,
# 'Expression3': function for computing x^(0.5)-5, 'Expression4': function for computing x^3 + 1 }
# Pass the value (input from the user) to the functions in the dictionary respectively. Then add the outputs of each function and print it
#
# Sample Input<br>
# 9<br>
# Sample Output<br>
# 829<br>
# <br>(Explanation)<br>
# {'Expression1':15,'Expression2':86,'Expression3':-2,''Expression4':730}<br>
# Exp1 : (2 * 9) -3 = 15<br>
# Exp2 : (9^2) +5 = 81+5 = 86<br>
# Exp1 : (9 ^ 0.5) - 5 = -2<br>
# Exp1 : (9 ^ 3) + 1 = 729 + 1 = 730<br>
# Sum : 15+86+(-2)+730=829
#
# #### Q18)
# Find the cumulative average of the list [5,7,3,6,9,8] using accumulate()
# and list comprehension. Result should be upto 2 decimal places
# Sample Output<br>
# [5.0, 6.0, 5.0, 5.25, 6.0, 6.33]
#
#
#
# #### Q19)
# A dictionary of fruits and their price is given for city A. Find fruit's price
# much they will price for city B. (Use map and lambda functions)<br>
# Formula : price_B = (price_A * Criteria_B) / Criteia_A<br>
# fruits_A = {'Mango':85, 'Watermelon':50, 'Guava':45,'Grapes':70}<br>
# Criteria_A: 4.7<br>
# Criteria_B: 11.34<br>
# Output:<br>
# Fruits_B: {'Mango': 205.08510638297872, 'Watermelon': 120.63829787234042, 'Guava': 108.57446808510637, 'Grapes': 168.89361702127658}<br>
#
#
# #### Q20)
# A list containing multiple lists is given. Convert each inner list into sets
# and find the intersection of all the sets.
# Use reduce function.<br>
# given_sets = [[7,3,12,45,78,13], [9,12,15,67,34,78], [19,20,78,12,25,95], [12,78,80,21,80],
# [13,14,12,15,16,75,76,77,78,79,80]]<br>
# Output: {12,78}
#
# #### Q21)
# Given below are a list of positive and negative words. Also a list of
# comments is provided. Segregate the comments based on metro and non-metro cities
# <br>
#
# Metro_city = ['Delhi','Kolkata', 'Mumbai', 'Bangalore']<br>
# Non_metro_city = ['Ayodhya','Shimla']<br>
# comments =
# ['Covid hits again in Delhi',
# 'Covid XE variant has its roots in Mumbai',
# 'Water shortage in Shimla has not been resolved completely',
# 'Authors have a community in Kolkata',
# 'AI based jobs are flooded in Bangalore',
# 'Diwali in Ayodhya went into Guinness records for lighting most diyas']<br>
#
# Output<br>
# ['Metro_city','Metro_city','Non_metro_city','Metro_city','Metro_city','Non_metro_city']
